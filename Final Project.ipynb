# %%
# !pip install matplotlib 

import operator
import matplotlib.pyplot as plt



class Job:
    #Job offer comparison
     # The init method or constructor
    def __init__(self, name, income, health, insurance, retirement, pretirement, union, taxes, move):
     
        # Instance Variable 
        self.name = name
        self.income = income  
        self.health = health
        self.insurance = insurance
        self.retirement = retirement
        self.pretirement = pretirement
        self.union = union
        self.taxes = taxes
        self.move = move
        self.pto = pto  
        self.happy = happy
        self.advancement = advancement
        
    #Information for job A
        
    name = input("Enter name of job A:")
    salary = int(input("Enter montly income: "))
    health = int(input("Enter monthly dollar amount of insurance premiums coved by employer:"))
    insurance = int(input("Enter monthly dollar amount of insurance premiums covered by you:"))
    retirement = int(input("Enter monthly dollar amount of retirement plan paid by employer:")) 
    pretirement = int(input("Enter monthly dollar amount of retirement or pension contribution paid by you:"))
    union = int(input("Enter monthly dollar amount of required union or other professional fees paid by you:"))
    taxes = int(input("Enter monthly dollar amount of state and local income taxes paid by you:"))
    move = int(input("Enter relocation cost to be paid by you for this job:")) 
    
    #Benefits for job A
    
    pto=int(input("Enter annual pto hours for job A (include paid vacation, sick time, holidays, etc.):"))
    happy = int(input("Rate your anticipated happiness with this company (1 = very happy, 0 = happy, -1 = it's a job):"))
    advancement = int(input("Rate advancement opportunities with this company (1 = multiple opportunities, 0 = unknown, -1 = advancement means leaving the company):"))

     
    
   #Information for job B
        
    nameb = input("Enter name of job B:")
    salaryb = int(input("Enter monthly salary: "))
    healthb = int(input("Enter monthly dollar amount of health insurance premium coved by employer:"))
    insuranceb = int(input("Enter monthly dollar amount of insurance premiums covered by you:"))
    retirementb = int(input("Enter monthly dollar amount of retirement plan paid by employer:")) 
    pretirementb = int(input("Enter monthly dollar amount of retirement or pension contribution paid by you:"))
    unionb = int(input("Enter monthly dollar amount of required union or other professional fees paid by you:"))
    taxesb = int(input("Enter monthly dollar amount of state and local income taxes paid by you:"))
    moveb = int(input("Enter relocation cost to be paid by you for this job:")) 
    
    #Benefits for job B
    
    ptob=int(input("Enter annual pto hours for job A (include paid vacation, sick time, holidays, etc.):"))
    happyb = int(input("Rate your anticipated happiness with this company (1 = very happy, 0 = happy, -1 = it's a job):"))
    advancementb = int(input("Rate advancement opportunities with this company (1 = multiple opportunities, 0 = unknown, -1 = advancement means leaving the company):"))
    print()

    jobA=(((salary+health-insurance+retirement-pretirement-union-taxes)*12)-move)
    jobB=(((salaryb+healthb-insuranceb+retirementb-pretirementb-unionb-taxesb)*12) - moveb)
    print("Monthly monetary value of job A:", (jobA))    
    print("Monthly monetary value of job B:", (jobB))
    print()

    
    benefitA = (((pto+happy+advancement)))
    benefitB = (((ptob+happyb+advancementb)))
    print("Job A benefit evaluation:", (benefitA))    
    print("Job B benefit evaluation:", (benefitB))
    print()
    
    
    
  
    #Compare monetary values of the jobs
    
    if jobA > jobB:
            print("Job A is the better monetary offer!")
    elif jobA == jobB:
            print ("Both jobs present an equal monetary offer!")
    else:
            print("Job B is the better monetary offer!")  
            
            
    # %matplotlib inline
    plt.style.use('ggplot')

    x = [name, nameb]
    MB = [jobA,jobB]

    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, MB, color='green')
    plt.xlabel("Job")
    plt.ylabel("Monetary Value")
    plt.title("Monetary Comparison")

    plt.xticks(x_pos, x)

    plt.show()
            
            
    #Compare job benefits     
            
    if benefitA > benefitB:
            print("Job A offers better benefits!")
    elif benefitA == benefitB:
            print ("Both jobs offer equal benefits!")
    else:
            print("Job B offers better benefits!")      
            
    
    # %matplotlib inline
    plt.style.use('ggplot')

    x = [name, nameb]
    B = [benefitA, benefitB]

    x_pos = [i for i, _ in enumerate(x)]

    plt.bar(x_pos, B, color='purple')
    plt.xlabel("Job")
    plt.ylabel("Benefit Score")
    plt.title("Benefit Comparison")

    plt.xticks(x_pos, x)

    plt.show()
# Out:
# Requirement already satisfied: matplotlib in c:\users\porce\miniconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (1.20.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\porce\miniconda3\lib\site-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: six in c:\users\porce\miniconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: six in c:\users\porce\miniconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: inquirer in c:\users\porce\miniconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: readchar==2.0.1 in c:\users\porce\miniconda3\lib\site-packages (from inquirer) (2.0.1)
# Requirement already satisfied: blessed==1.17.6 in c:\users\porce\miniconda3\lib\site-packages (from inquirer) (1.17.6)
# Requirement already satisfied: python-editor==1.0.4 in c:\users\porce\miniconda3\lib\site-packages (from inquirer) (1.0.4)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\porce\miniconda3\lib\site-packages (from blessed==1.17.6->inquirer) (0.2.5)
# Requirement already satisfied: jinxed>=0.5.4 in c:\users\porce\miniconda3\lib\site-packages (from blessed==1.17.6->inquirer) (1.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\porce\miniconda3\lib\site-packages (from blessed==1.17.6->inquirer) (1.15.0)
# Requirement already satisfied: ansicon in c:\users\porce\miniconda3\lib\site-packages (from jinxed>=0.5.4->blessed==1.17.6->inquirer) (1.89.0)
# Requirement already satisfied: pick in c:\users\porce\miniconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: windows-curses in c:\users\porce\miniconda3\lib\site-packages (from pick) (2.2.0)
# Enter name of job A:FL
# Enter montly income: 234523
# Enter monthly dollar amount of insurance premiums coved by employer:425
# Enter monthly dollar amount of insurance premiums covered by you:2345
# Enter monthly dollar amount of retirement plan paid by employer:2345
# Enter monthly dollar amount of retirement or pension contribution paid by you:254
# Enter monthly dollar amount of required union or other professional fees paid by you:2345
# Enter monthly dollar amount of state and local income taxes paid by you:2345
# Enter relocation cost to be paid by you for this job:2345
# Enter annual pto hours for job A (include paid vacation, sick time, holidays, etc.):12
# Rate your anticipated happiness with this company (1 = very happy, 0 = happy, -1 = it's a job):1
# Rate advancement opportunities with this company (1 = multiple opportunities, 0 = unknown, -1 = advancement means leaving the company):1
# Enter name of job B:ijsdkjg
# Enter monthly salary: 24634
# Enter monthly dollar amount of health insurance premium coved by employer:5234
# Enter monthly dollar amount of insurance premiums covered by you:5435
# Enter monthly dollar amount of retirement plan paid by employer:4563456
# Enter monthly dollar amount of retirement or pension contribution paid by you:3254
# Enter monthly dollar amount of required union or other professional fees paid by you:2345
# Enter monthly dollar amount of state and local income taxes paid by you:532
# Enter relocation cost to be paid by you for this job:2
# Enter annual pto hours for job A (include paid vacation, sick time, holidays, etc.):23
# Rate your anticipated happiness with this company (1 = very happy, 0 = happy, -1 = it's a job):1
# Rate advancement opportunities with this company (1 = multiple opportunities, 0 = unknown, -1 = advancement means leaving the company):1
#
# Monthly monetary value of job A: 2757703
# Monthly monetary value of job B: 54981094
#
# Job A benefit evaluation: 14
# Job B benefit evaluation: 25
#
# Job B is the better monetary offer!
# Job B offers better benefits!

# %% [markdown]
# ##
